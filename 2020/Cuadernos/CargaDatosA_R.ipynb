# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#MARGIN" data-toc-modified-id="MARGIN-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>MARGIN</a></span></li><li><span><a href="#EJERCICIO" data-toc-modified-id="EJERCICIO-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EJERCICIO</a></span></li></ul></div>

# %%
library(readxl)
# Out:
# Error in library(readxl): there is no package called 'readxl'
# Traceback:
#
# 1. library(readxl)

# %%
install.packages(readxl)
# Out:
# Error in install.packages(readxl): objeto 'readxl' no encontrado
# Traceback:
#
# 1. install.packages(readxl)

# %%
install.packages('readxl')
# Out:
# Installing package into 'C:/Users/Sala_706/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'rematch', 'pkgconfig', 'hms', 'prettyunits', 'R6', 'cellranger', 'tibble', 'progress'
# package 'rematch' successfully unpacked and MD5 sums checked
# package 'pkgconfig' successfully unpacked and MD5 sums checked
# package 'hms' successfully unpacked and MD5 sums checked
# package 'prettyunits' successfully unpacked and MD5 sums checked
# package 'R6' successfully unpacked and MD5 sums checked
# package 'cellranger' successfully unpacked and MD5 sums checked
# package 'tibble' successfully unpacked and MD5 sums checked
# package 'progress' successfully unpacked and MD5 sums checked
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Sala_706\AppData\Local\Temp\RtmpOkhPbD\downloaded_packages

# %%
library(readxl)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.2"

# %%
data<-read_excel("Documentos/Datos/Base1.xlsx",col_names = T,sheet = "Hoja2")
# Out:
# Error: `path` does not exist: 'Documentos/Datos/Base1.xlsx'
# Traceback:
#
# 1. read_excel("Documentos/Datos/Base1.xlsx", col_names = T, sheet = "Hoja2")
# 2. check_file(path)
# 3. stop("`path` does not exist: ", sQuote(path), call. = FALSE)

# %%
data<-read_excel("Base1.xlsx",col_names = T,sheet = "Hoja2")
# Out:
# New names:
# * `` -> ...1

# %%
data
# Out:
#    ...1            SO2 Neg,Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix          10 70.3      213      582       6.0    7.05          36
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# 6  Buffalo          11 47.1      391      463      12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little           13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville     14 68.4      136      529       8.8   54.47         116
# 10 Omaha            14 51.5      181      347      10.9   30.18          98
# 11 Milwaukee        16 45.7      569      717      11.8   29.07         123
# ...

# %%
data<-data.frame(data)
head(data)
data
# Out:
#   ...1         SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1 Phoenix      10  70.3     213       582       6.0    7.05          36
# 2 Miami        10  75.5     207       335       9.0   59.80         128
# 3 Memphis      10  61.6     337       624       9.2   49.10         105
# 4 Houston      10  68.9     721      1233      10.8   48.19         103
# 5 Alburquerque 11  56.8      46       244       8.9    7.77          58
# 6 Buffalo      11  47.1     391       463      12.4   36.11         166
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix          10 70.3      213      582       6.0    7.05          36
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# ...

# %%
str(data)
# Out:
# 'data.frame':	41 obs. of  8 variables:
#  $ ...1         : chr  "Phoenix" "Miami" "Memphis" "Houston" ...
#  $ SO2          : num  10 10 10 10 11 11 110 13 14 14 ...
#  $ Neg.Temp     : num  70.3 75.5 61.6 68.9 56.8 47.1 50.6 61 68.4 51.5 ...
#  $ Empresas     : num  213 207 337 721 46 ...
#  $ Población    : num  582 335 624 1233 244 ...
#  $ Viento       : num  6 9 9.2 10.8 8.9 12.4 10.4 8.2 8.8 10.9 ...
#  $ Precipitación: num  7.05 59.8 49.1 48.19 7.77 ...
#  $ Dias         : num  36 128 105 103 58 166 122 100 116 98 ...

# %%
data2=read.csv("data_.txt",dec = ".",sep=";")

# %%
data2<-data.frame(data2)
head(data2)
# Out:
#   x1 x2 x3 x4 x5
# 1 1  2  3  4   5
# 2 6  7  8  9  10

# %%
dim(data2)
# Out:
# [1] 2 5

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# %%
data3<-read.csv(url,header=F)
data3<-data.frame(data3)
data3
# Out:
#     V1  V2  V3  V4  V5  V6   V7    V8  V9
# 1    6  148 72  35    0 33.6 0.627 50  1
# 2    1   85 66  29    0 26.6 0.351 31  0
# 3    8  183 64   0    0 23.3 0.672 32  1
# 4    1   89 66  23   94 28.1 0.167 21  0
# 5    0  137 40  35  168 43.1 2.288 33  1
# 6    5  116 74   0    0 25.6 0.201 30  0
# 7    3   78 50  32   88 31.0 0.248 26  1
# 8   10  115  0   0    0 35.3 0.134 29  0
# 9    2  197 70  45  543 30.5 0.158 53  1
# 10   8  125 96   0    0  0.0 0.232 54  1
# 11   4  110 92   0    0 37.6 0.191 30  0
# 12  10  168 74   0    0 38.0 0.537 34  1
# 13  10  139 80   0    0 27.1 1.441 57  0
# 14   1  189 60  23  846 30.1 0.398 59  1
# 15   5  166 72  19  175 25.8 0.587 51  1
# 16   7  100  0   0    0 30.0 0.484 32  1
# 17   0  118 84  47  230 45.8 0.551 31  1
# 18   7  107 74   0    0 29.6 0.254 31  1
# 19   1  103 30  38   83 43.3 0.183 33  0
# 20   1  115 70  30   96 34.6 0.529 32  1
# 21   3  126 88  41  235 39.3 0.704 27  0
# 22   8   99 84   0    0 35.4 0.388 50  0
# ...

# %%
data[1:10,]
# Out:
#    ...1         SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix       10 70.3      213      582       6.0    7.05          36
# 2  Miami         10 75.5      207      335       9.0   59.80         128
# 3  Memphis       10 61.6      337      624       9.2   49.10         105
# 4  Houston       10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque  11 56.8       46      244       8.9    7.77          58
# 6  Buffalo       11 47.1      391      463      12.4   36.11         166
# 7  Chicago      110 50.6     3344     3369      10.4   34.44         122
# 8  Little        13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville  14 68.4      136      529       8.8   54.47         116
# 10 Omaha         14 51.5      181      347      10.9   30.18          98

# %%
data[1:10,1,2]
# Out:
#  [1] "Phoenix"      "Miami"        "Memphis"      "Houston"      "Alburquerque"
#  [6] "Buffalo"      "Chicago"      "Little"       "Jacksonville" "Omaha"

# %%
data[1:5,]
# Out:
#   ...1         SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1 Phoenix      10  70.3     213       582       6.0    7.05          36
# 2 Miami        10  75.5     207       335       9.0   59.80         128
# 3 Memphis      10  61.6     337       624       9.2   49.10         105
# 4 Houston      10  68.9     721      1233      10.8   48.19         103
# 5 Alburquerque 11  56.8      46       244       8.9    7.77          58

# %%
data[1:3,1]
# Out:
# [1] "Phoenix" "Miami"   "Memphis"

# %%
data4=data[c(1,3,5),c(1,2,4,6)]
data4
# Out:
#   ...1         SO2 Empresas Viento
# 1 Phoenix      10  213      6.0
# 3 Memphis      10  337      9.2
# 5 Alburquerque 11   46      8.9

# %%
cbind(data4,data[1:3,1:4])
# Out:
#   ...1         SO2 Empresas Viento ...1    SO2 Neg.Temp Empresas
# 1 Phoenix      10  213      6.0    Phoenix 10  70.3     213
# 3 Memphis      10  337      9.2    Miami   10  75.5     207
# 5 Alburquerque 11   46      8.9    Memphis 10  61.6     337

# %%
data[,-1]
# Out:
#    SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1   10 70.3      213      582       6.0    7.05          36
# 2   10 75.5      207      335       9.0   59.80         128
# 3   10 61.6      337      624       9.2   49.10         105
# 4   10 68.9      721     1233      10.8   48.19         103
# 5   11 56.8       46      244       8.9    7.77          58
# 6   11 47.1      391      463      12.4   36.11         166
# 7  110 50.6     3344     3369      10.4   34.44         122
# 8   13 61.0       91      132       8.2   48.52         100
# 9   14 68.4      136      529       8.8   54.47         116
# 10  14 51.5      181      347      10.9   30.18          98
# 11  16 45.7      569      717      11.8   29.07         123
# 12  17 51.9      454      515       9.0   12.95          86
# 13  18 59.4      275      448       7.9   46.00         119
# 14  23 54.0      462      453       7.1   39.04         132
# 15  24 61.5      368      497       9.1   48.34         115
# ...

# %%
data[-1,]
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# 6  Buffalo          11 47.1      391      463      12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little           13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville     14 68.4      136      529       8.8   54.47         116
# 10 Omaha            14 51.5      181      347      10.9   30.18          98
# 11 Milwaukee        16 45.7      569      717      11.8   29.07         123
# 12 Denver           17 51.9      454      515       9.0   12.95          86
# ...

# %%
data[,-1:-3]
# Out:
#    Empresas Población Viento Precipitación Dias
# 1   213      582       6.0    7.05          36
# 2   207      335       9.0   59.80         128
# 3   337      624       9.2   49.10         105
# 4   721     1233      10.8   48.19         103
# 5    46      244       8.9    7.77          58
# 6   391      463      12.4   36.11         166
# 7  3344     3369      10.4   34.44         122
# 8    91      132       8.2   48.52         100
# 9   136      529       8.8   54.47         116
# 10  181      347      10.9   30.18          98
# 11  569      717      11.8   29.07         123
# 12  454      515       9.0   12.95          86
# 13  275      448       7.9   46.00         119
# 14  462      453       7.1   39.04         132
# 15  368      497       9.1   48.34         115
# 16  266      540       8.6   37.01         134
# 17  197      299       7.6   42.59         115
# 18  361      746       9.7   38.74         121
# 19  434      757       9.3   38.89         111
# ...

# %% [markdown]
# ## MARGIN
# Indica si se trabaja por fila o columna
# 1 fila
# 2 columna
# Para aplicar una función en una columna o fila, puedes usar el método apply() de DataFrame.

# %%
apply(data[,-1],MARGIN = 2,mean)
# Out:
#           SO2      Neg.Temp      Empresas     Población        Viento
#     30.048780     55.763415    463.097561    608.609756      9.443902
# Precipitación          Dias
#     36.769024    113.902439

# %%
((10+70.3+213+582+6+7.05+36)/7)
# Out:
# [1] 132.05

# %% [markdown]
# Para eliminar filas duplicadas de un DataFrame, usa el método duplicated() o unique() del DataFrame.

# %%
datad=rbind(data,data[1:3,])
datad
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix          10 70.3      213      582       6.0    7.05          36
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# 6  Buffalo          11 47.1      391      463      12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little           13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville     14 68.4      136      529       8.8   54.47         116
# 10 Omaha            14 51.5      181      347      10.9   30.18          98
# 11 Milwaukee        16 45.7      569      717      11.8   29.07         123
# ...

# %%
duplicated(datad)
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE

# %%
datad[duplicated(datad),]
# Out:
#    ...1    SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 42 Phoenix 10  70.3     213      582       6.0     7.05          36
# 43 Miami   10  75.5     207      335       9.0    59.80         128
# 44 Memphis 10  61.6     337      624       9.2    49.10         105

# %%
c(T,F,T,T,F)
# Out:
# [1]  TRUE FALSE  TRUE  TRUE FALSE

# %%
datad[c(T,F,T,T,F),c(F,T,F,T)]
# Out:
#    SO2 Empresas Viento Dias
# 1  10   213      6.0    36
# 3  10   337      9.2   105
# 4  10   721     10.8   103
# 6  11   391     12.4   166
# 8  13    91      8.2   100
# 9  14   136      8.8   116
# 11 16   569     11.8   123
# 13 18   275      7.9   119
# 14 23   462      7.1   132
# 16 26   266      8.6   134
# 18 28   361      9.7   121
# 19 29   434      9.3   111
# 21 30   291      8.3   123
# 23 31    35      6.5   148
# 24 35  1064     10.1   129
# 26 46    44      8.8   135
# 28 56   412      9.0   127
# 29 61   347      9.4   147
# 31 69  1692      9.6   115
# 33  9   641     10.9    78
# 34 94   343     10.6   125
# 36 12   453      8.7    67
# 38 56   775      9.5   105
# 39 17   104     11.2   103
# 41 29   699     10.6   137
# 43 10   207      9.0   128
# 44 10   337      9.2   105

# %%
datad[!duplicated(datad),]
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix          10 70.3      213      582       6.0    7.05          36
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# 6  Buffalo          11 47.1      391      463      12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little           13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville     14 68.4      136      529       8.8   54.47         116
# 10 Omaha            14 51.5      181      347      10.9   30.18          98
# 11 Milwaukee        16 45.7      569      717      11.8   29.07         123
# ...

# %% [markdown]
# Agregar una fila al final (Boyaca)

# %%
boy=c("Boyaca",29,43.5,699,744,10.6,25.94,137)
rbind(datad,boy)
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix         10  70.3     213      582       6      7.05          36
# 2  Miami           10  75.5     207      335       9      59.8          128
# 3  Memphis         10  61.6     337      624       9.2    49.1          105
# 4  Houston         10  68.9     721      1233      10.8   48.19         103
# 5  Alburquerque    11  56.8     46       244       8.9    7.77          58
# 6  Buffalo         11  47.1     391      463       12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little          13  61       91       132       8.2    48.52         100
# 9  Jacksonville    14  68.4     136      529       8.8    54.47         116
# 10 Omaha           14  51.5     181      347       10.9   30.18         98
# 11 Milwaukee       16  45.7     569      717       11.8   29.07         123
# ...

# %%
boy2=c("Boyac",29,43.5,699,744,10.6,25.94,137)
rbind(datad,boy2)
boy=c("Boyaca",29,43.5,699,744,10.6,25.94,137)
rbind(datad,boy)
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix         10  70.3     213      582       6      7.05          36
# 2  Miami           10  75.5     207      335       9      59.8          128
# 3  Memphis         10  61.6     337      624       9.2    49.1          105
# 4  Houston         10  68.9     721      1233      10.8   48.19         103
# 5  Alburquerque    11  56.8     46       244       8.9    7.77          58
# 6  Buffalo         11  47.1     391      463       12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little          13  61       91       132       8.2    48.52         100
# 9  Jacksonville    14  68.4     136      529       8.8    54.47         116
# 10 Omaha           14  51.5     181      347       10.9   30.18         98
# 11 Milwaukee       16  45.7     569      717       11.8   29.07         123
# ...

# %% [markdown]
# Como se ve si se repiten ciudades en la base anterior

# %%
datad[,1]
# Out:
#  [1] "Phoenix"         "Miami"           "Memphis"         "Houston"
#  [5] "Alburquerque"    "Buffalo"         "Chicago"         "Little"
#  [9] "Jacksonville"    "Omaha"           "Milwaukee"       "Denver"
# [13] "Nashville"       "Cincinnati"      "Atlanta"         "Columbus"
# [17] "Richmond"        "Indianapolis"    "Washington"      "Seattle"
# [21] "Louisville"      "Norfolk"         "Charleston"      "Detroit"
# [25] "Wilmington"      "Albany"          "Baltimore"       "Hartford"
# [29] "Pittsburgh"      "Cleveland"       "Philadelphia"    "Wichita"
# [33] "Dallas"          "Providence"      "Kansas"          "San"
# [37] "Salt"            "St,"             "Des"             "New"
# [41] "Minneapolis-St," "Phoenix"         "Miami"           "Memphis"

# %%
duplicated(datad[,1])
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE

# %%
unique(datad)
# Out:
#    ...1            SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 1  Phoenix          10 70.3      213      582       6.0    7.05          36
# 2  Miami            10 75.5      207      335       9.0   59.80         128
# 3  Memphis          10 61.6      337      624       9.2   49.10         105
# 4  Houston          10 68.9      721     1233      10.8   48.19         103
# 5  Alburquerque     11 56.8       46      244       8.9    7.77          58
# 6  Buffalo          11 47.1      391      463      12.4   36.11         166
# 7  Chicago         110 50.6     3344     3369      10.4   34.44         122
# 8  Little           13 61.0       91      132       8.2   48.52         100
# 9  Jacksonville     14 68.4      136      529       8.8   54.47         116
# 10 Omaha            14 51.5      181      347      10.9   30.18          98
# 11 Milwaukee        16 45.7      569      717      11.8   29.07         123
# ...

# %% [markdown]
# Valores cuantitativos

# %%
summary(data)
# Out:
#      ...1                SO2            Neg.Temp        Empresas
#  Length:41          Min.   :  8.00   Min.   :43.50   Min.   :  35.0
#  Class :character   1st Qu.: 13.00   1st Qu.:50.60   1st Qu.: 181.0
#  Mode  :character   Median : 26.00   Median :54.60   Median : 347.0
#                     Mean   : 30.05   Mean   :55.76   Mean   : 463.1
#                     3rd Qu.: 35.00   3rd Qu.:59.30   3rd Qu.: 462.0
#                     Max.   :110.00   Max.   :75.50   Max.   :3344.0
#    Población          Viento       Precipitación        Dias
#  Min.   :  71.0   Min.   : 6.000   Min.   : 7.05   Min.   : 36.0
#  1st Qu.: 299.0   1st Qu.: 8.700   1st Qu.:30.96   1st Qu.:103.0
#  Median : 515.0   Median : 9.300   Median :38.74   Median :115.0
#  Mean   : 608.6   Mean   : 9.444   Mean   :36.77   Mean   :113.9
#  3rd Qu.: 717.0   3rd Qu.:10.600   3rd Qu.:43.11   3rd Qu.:128.0
#  Max.   :3369.0   Max.   :12.700   Max.   :59.80   Max.   :166.0

# %%
boxplot(data[-1])
# Out:
# plot without title

# %%
plot(data[,5],data[,2])
# Out:
# plot without title

# %%
data[,1]=="Omaha"
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE

# %%
data[data[,1]=="Omaha",]
# Out:
#    ...1  SO2 Neg.Temp Empresas Población Viento Precipitación Dias
# 10 Omaha 14  51.5     181      347       10.9   30.18         98

# %%
$ help
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:1: inesperado '$'
# 1: $
#     ^
# Traceback:

# %% [markdown]
# ## EJERCICIO

# %%
ejer=read.csv("craneos.txt",dec = ".",sep=";")
ejer
# Out:
#    X  Longitud Anchura Altura Altura.cara Anchuro.Cara Tipo
# 1   1 21       25      22     14          17           R1
# 2   2  7        5       3      2           4           R1
# 3   3  2        2       3      8           3           R1
# 4   4  3       24      12      3           7           R1
# 5   5 10       12       4     19          15           R1
# 6   6 11       19      19     12           8           R1
# 7   7 13       19       5     10          14           R1
# 8   8 13       11      12     14          11           R1
# 9   9  8        8       8      9          12           R1
# 10 10  1       13       9      1           6           R1
# 11 11 12        7      15     11           5           R1
# 12 12  5       22      11      4          24           R1
# 13 13 14       13      10     16          14           R1
# 14 14 17       23       1     18          21           R1
# 15 15  3        2       9      6           2           R1
# ...

# %%
ejer[-c(22:32),-1]
# Out:
#    Longitud Anchura Altura Altura.cara Anchuro.Cara Tipo
# 1  21       25      22     14          17           R1
# 2   7        5       3      2           4           R1
# 3   2        2       3      8           3           R1
# 4   3       24      12      3           7           R1
# 5  10       12       4     19          15           R1
# 6  11       19      19     12           8           R1
# 7  13       19       5     10          14           R1
# 8  13       11      12     14          11           R1
# 9   8        8       8      9          12           R1
# 10  1       13       9      1           6           R1
# 11 12        7      15     11           5           R1
# 12  5       22      11      4          24           R1
# 13 14       13      10     16          14           R1
# 14 17       23       1     18          21           R1
# 15  3        2       9      6           2           R1
# 16  6       15      15     10          12           R1
# ...

# %%
ejer[header"Anchura.cara"]
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:12: unexpected string constant
# 1: ejer[header"Anchura.cara"
#                ^
# Traceback:

# %%
ejer[ejer$Longitud<=
